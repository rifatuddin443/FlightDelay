# %%
# !git clone https://github.com/rifatuddin443/FlightDelay.git
# Out:
# Cloning into 'FlightDelay'...
# Updating files:  99% (430/434)
# Updating files: 100% (434/434)
# Updating files: 100% (434/434), done.

# %%
# %pip install torch_geometric
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python threestagev2.py --stage1_epochs 7 --stage2_epochs 10 --stage3_epochs 10 --epsilon 5
